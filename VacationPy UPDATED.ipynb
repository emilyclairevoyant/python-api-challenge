# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# !pip install cartopy
# !pip install geoviews
# !pip install pyproj
# Import API key
from api_keys import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="fac337bc-273b-4e95-ba65-412c33d5e032" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0837d824-5957-478c-b7e7-3d4c1c8c8362":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"2a23667fe9274b16bf450a71067e44e7","client_comm_id":"029bb68fa5ce4f3f96bd45252d5160e2"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"0837d824-5957-478c-b7e7-3d4c1c8c8362","roots":{"p1002":"fac337bc-273b-4e95-ba65-412c33d5e032"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# Requirement already satisfied: cartopy in /opt/anaconda3/lib/python3.12/site-packages (0.23.0)
# Requirement already satisfied: numpy>=1.21 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.5 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy) (3.8.4)
# Requirement already satisfied: shapely>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy) (2.0.5)
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.3 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from pyproj>=3.3.1->cartopy) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->cartopy) (1.16.0)
# Requirement already satisfied: geoviews in /opt/anaconda3/lib/python3.12/site-packages (1.12.0)
# Requirement already satisfied: bokeh<3.5.0,>=3.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (3.4.1)
# Requirement already satisfied: cartopy>=0.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (0.23.0)
# Requirement already satisfied: holoviews>=1.16.0 in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (1.19.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (23.2)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (1.26.4)
# Requirement already satisfied: shapely in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (2.0.5)
# Requirement already satisfied: param in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (2.1.0)
# Requirement already satisfied: panel>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (1.4.4)
# Requirement already satisfied: pyproj in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: xyzservices in /opt/anaconda3/lib/python3.12/site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: Jinja2>=2.9 in /opt/anaconda3/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in /opt/anaconda3/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (1.2.0)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /opt/anaconda3/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in /opt/anaconda3/lib/python3.12/site-packages (from bokeh<3.5.0,>=3.4.0->geoviews) (6.4.1)
# Requirement already satisfied: matplotlib>=3.5 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy>=0.18.0->geoviews) (3.8.4)
# Requirement already satisfied: pyshp>=2.3 in /opt/anaconda3/lib/python3.12/site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: colorcet in /opt/anaconda3/lib/python3.12/site-packages (from holoviews>=1.16.0->geoviews) (3.1.0)
# Requirement already satisfied: pyviz-comms>=2.1 in /opt/anaconda3/lib/python3.12/site-packages (from holoviews>=1.16.0->geoviews) (3.0.2)
# Requirement already satisfied: markdown in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (4.66.4)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.12/site-packages (from panel>=1.0.0->geoviews) (4.11.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from pyproj->geoviews) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from Jinja2>=2.9->bokeh<3.5.0,>=3.4.0->geoviews) (2.1.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.5->cartopy>=0.18.0->geoviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2->bokeh<3.5.0,>=3.4.0->geoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas>=1.2->bokeh<3.5.0,>=3.4.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /opt/anaconda3/lib/python3.12/site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->panel>=1.0.0->geoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->panel>=1.0.0->geoviews) (2.2.2)
# Requirement already satisfied: pyproj in /opt/anaconda3/lib/python3.12/site-packages (3.6.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.12/site-packages (from pyproj) (2024.7.4)

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0        0              college  64.8569 -147.8028     21.86        57
# 1        1  termas de rio hondo -27.4998  -64.8604     22.74        42
# 2        2        fort mcmurray  56.7268 -111.3810     22.73        43
# 3        3            iskateley  67.6803   53.1512      6.48        83
# 4        4                 tual  -5.6667  132.7500     25.25        85
#
#    Cloudiness  Wind Speed Country        Date
# 0          20        2.57      US  1722883005
# 1           8        2.95      AR  1722883006
# 2           0        3.60      CA  1722882779
# 3           3        5.32      RU  1722883008
# 4          97        9.29      ID  1722883009

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City"
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_vacay_df = city_data_df[((city_data_df['Max Temp'] < 27) & (city_data_df['Max Temp'] > 21)) & ((city_data_df['Wind Speed'] < 4.5) | (city_data_df['Cloudiness'] == 0))]

# Drop any rows with null values
ideal_vacay_df.dropna()

# Display sample data
ideal_vacay_df.head()
# Out:
#     City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0         0              college  64.8569 -147.8028     21.86        57
# 1         1  termas de rio hondo -27.4998  -64.8604     22.74        42
# 2         2        fort mcmurray  56.7268 -111.3810     22.73        43
# 11       11           shyryayeve  47.3805   30.1964     24.62        29
# 16       16               badger  64.8000 -147.5333     22.03        58
#
#     Cloudiness  Wind Speed Country        Date
# 0           20        2.57      US  1722883005
# 1            8        2.95      AR  1722883006
# 2            0        3.60      CA  1722882779
# 11         100        1.36      UA  1722883017
# 16          20        2.57      US  1722883024

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df.copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df.head()
# Out:
#    City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0        0              college  64.8569 -147.8028     21.86        57
# 1        1  termas de rio hondo -27.4998  -64.8604     22.74        42
# 2        2        fort mcmurray  56.7268 -111.3810     22.73        43
# 3        3            iskateley  67.6803   53.1512      6.48        83
# 4        4                 tual  -5.6667  132.7500     25.25        85
#
#    Cloudiness  Wind Speed Country        Date Hotel Name
# 0          20        2.57      US  1722883005
# 1           8        2.95      AR  1722883006
# 2           0        3.60      CA  1722882779
# 3           3        5.32      RU  1722883008
# 4          97        9.29      ID  1722883009

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Define the categories variable
categories = "accommodation.hotel"
base_url = "https://api.geoapify.com/v2/places"

# Set parameters to search for a hotel
radius = 10000
params = {
    "categories": categories,
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lon = row["Lng"]

    # Update the bias parameter with the correct format based on current latitude and longitude
    bias = f"proximity:{lon},{lat}"
    params["bias"] = bias

    name_address = requests.get(base_url, params=params)
    name_address_json = name_address.json()

    try:
        hotel_name = name_address_json["features"][0]["properties"]["name"]
    except (KeyError, IndexError) as e:
        print(f"Error finding hotel for {hotel_df.loc[index, 'City']}: {e}")
        hotel_name = "No hotel found"

    hotel_df.loc[index, "Hotel Name"] = hotel_name

    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_name}")

# Display the DataFrame with the hotel names only
hotel_df.head()

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Starting hotel search
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# termas de rio hondo - nearest hotel: Hotel Panamericano
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# iskateley - nearest hotel: Авантаж
# tual - nearest hotel: Suita
# Error finding hotel for paragominas: 'name'
# paragominas - nearest hotel: No hotel found
# papatowai - nearest hotel: Catlins Woodstock Lodge & Camp
# selfoss - nearest hotel: Miðgarður
# broken hill - nearest hotel: Ibis Styles
# port-aux-francais - nearest hotel: Keravel
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# Error finding hotel for shyryayeve: 'name'
# shyryayeve - nearest hotel: No hotel found
# sinop - nearest hotel: Yıldız Country Hotel Sinop
# hassi messaoud - nearest hotel: AMC
# olonkinbyen - nearest hotel: Hótel Norðurljós
# albany - nearest hotel: Tru
# badger - nearest hotel: Clarion Hotel & Suites
# mikun' - nearest hotel: Саквояж
# adamstown - nearest hotel: Chez Bianca & Benoit
# kavieng - nearest hotel: Kavieng Hotel
# fisterra - nearest hotel: Hotel Temático do Banco Azul
# kerikeri - nearest hotel: Avalon Resort
# udachny - nearest hotel: Вилюй
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# Error finding hotel for camacupa: 'name'
# camacupa - nearest hotel: No hotel found
# kingston - nearest hotel: Aphrodite Hotel
# carnarvon - nearest hotel: Monkey Mia Dolphin Resort
# Error finding hotel for bilibino: 'name'
# bilibino - nearest hotel: No hotel found
# sambalpur - nearest hotel: Harjit Residency
# Error finding hotel for yellowknife: 'name'
# yellowknife - nearest hotel: No hotel found
# bethel - nearest hotel: Hampton Inn Danbury
# blackmans bay - nearest hotel: Villa Howden
# Error finding hotel for lebu: 'name'
# lebu - nearest hotel: No hotel found
# kambar - nearest hotel: Hotel Chacha
# manokwari - nearest hotel: Hotel Arfak
# mammoth lakes - nearest hotel: Travelodge Mammoth Lakes
# luchegorsk - nearest hotel: Мираж
# cheadle - nearest hotel: The Manor
# pisco - nearest hotel: La Portada
# leh - nearest hotel: Kang Lha Chen
# myrina - nearest hotel: Ήφαιστος
# iqaluit - nearest hotel: Frobisher Inn
# waitangi - nearest hotel: Hotel Chathams
# chonchi - nearest hotel: Hotel Huildín
# Error finding hotel for kodiak: 'name'
# kodiak - nearest hotel: No hotel found
# Error finding hotel for uzhur: 'name'
# uzhur - nearest hotel: No hotel found
# margaret river - nearest hotel: Margaret River Hotel
# quimili - nearest hotel: Parodi
# bredasdorp - nearest hotel: Victoria Hotel
# sadjoavato - nearest hotel: Hotel Gargotte la terrasse
# crucecita - nearest hotel: Santa Lucía
# karratha - nearest hotel: Karratha International Hotel
# whitehorse - nearest hotel: Town & Mountain Hotel
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# puerto baquerizo moreno - nearest hotel: Dory's House
# concepcion - nearest hotel: Hotel One (ex-Biobio)
# acapulco de juarez - nearest hotel: Hotel del Valle
# shimoda - nearest hotel: ホテルウラガ
# richfield - nearest hotel: Sonesta Simply Suites Minneapolis Richfield
# hermanus - nearest hotel: Aloe guest house
# mandera - nearest hotel: Kornesh Hotel and Lodging
# kigoma - nearest hotel: sunset vista hotel
# ati - nearest hotel: Consulat Hotel
# afaahiti - nearest hotel: Omati Lodge
# klyuchi - nearest hotel: Туристическая гостиница
# hamilton - nearest hotel: North Vista Manor
# qaqortoq - nearest hotel: Hotel Qaqortoq
# ajaccio - nearest hotel: Hôtel Sole e Monte
# port pirie - nearest hotel: Ellen Hotel
# Error finding hotel for p'ot'i: 'name'
# p'ot'i - nearest hotel: No hotel found
# ponta delgada - nearest hotel: Hotel Talisman
# flying fish cove - nearest hotel: Christmas Island Lodge
# thompson - nearest hotel: Thompson Inn
# bengkulu - nearest hotel: Dena Hotel
# owando - nearest hotel: Hotel de l'Eglise
# shwebo - nearest hotel: Pyi Shwe Theingha
# yaren - nearest hotel: Aiwo Hotel
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# ust'-ilimsk - nearest hotel: Усть-Илимск
# sangin - nearest hotel: هوټل
# pacific grove - nearest hotel: Pacific Grove Inn
# prineville - nearest hotel: Best Western
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# alamogordo - nearest hotel: Days Inn Alamogordo
# praia da vitoria - nearest hotel: Salles
# remire-montjoly - nearest hotel: Complexe Belova
# tibati - nearest hotel: Hôtel Calypso Annexe
# puerto leguizamo - nearest hotel: Hotel Girasoles
# isafjordur - nearest hotel: Hótel Horn
# grytviken - nearest hotel: Shorty's Motel
# lorengau - nearest hotel: Seeadler Bay Hotel
# zakamensk - nearest hotel: Сона
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# hiriyur - nearest hotel: Hotel Surya
# geraldton - nearest hotel: Ocean Centre Hotel
# Error finding hotel for baukau: 'name'
# baukau - nearest hotel: No hotel found
# el calafate - nearest hotel: Hostería Las Avutardas
# mwene-ditu - nearest hotel: Hôtel KAMAS
# moengo - nearest hotel: Amazonie accueil
# iron river - nearest hotel: AmericInn
# al fqih ben calah - nearest hotel: Hotel Oum Elfadl
# jamestown - nearest hotel: DoubleTree Jamestown
# sandnessjoen - nearest hotel: Scandic Syv Søstre
# lihue - nearest hotel: Kauai Palms
# ituango - nearest hotel: Palacio Municipal - Hotel Ituango
# Error finding hotel for edinburgh of the seven seas: list index out of range
# edinburgh of the seven seas - nearest hotel: No hotel found
# riohacha - nearest hotel: IMPERIAL
# mabaruma - nearest hotel: Monty Brooms Hotel
# Error finding hotel for port alfred: 'name'
# port alfred - nearest hotel: No hotel found
# vorgashor - nearest hotel: София
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# longyearbyen - nearest hotel: The Vault
# port mathurin - nearest hotel: Escale Vacances
# tura - nearest hotel: Hotel Polo Orchid
# juiz de fora - nearest hotel: Hotel Constantino
# nyurba - nearest hotel: Марина
# lata - nearest hotel: Residencial Botânico
# Error finding hotel for laibin: 'name'
# laibin - nearest hotel: No hotel found
# changping - nearest hotel: 速8酒店
# west island - nearest hotel: Cocos Village Bungalows
# igarka - nearest hotel: Заполярье
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# vanimo - nearest hotel: CBC Guesthouse
# klaksvik - nearest hotel: Hotel Klaksvik
# merizo village - nearest hotel: Leo Palace
# codrington - nearest hotel: 54 on Bank
# Error finding hotel for yerofey pavlovich: 'name'
# yerofey pavlovich - nearest hotel: No hotel found
# sullivan - nearest hotel: Holiday Inn Express & Suites
# Error finding hotel for utrik: 'name'
# utrik - nearest hotel: No hotel found
# nieuw amsterdam - nearest hotel: Leonsberg Lodge
# agat village - nearest hotel: Navy Getway Inns & Suites
# torrington - nearest hotel: Yankee Pedlar Inn
# hawaiian paradise park - nearest hotel: Lava Tree Tropic Inn
# sorong - nearest hotel: Hotel Membramo Marina
# alotau - nearest hotel: Alotau International Hotel
# qianzhou - nearest hotel: JinHuang Hotel
# tazovsky - nearest hotel: Тазовчанка
# avarua - nearest hotel: Paradise Inn
# kosh-agach - nearest hotel: Заря
# arawa - nearest hotel: Bovotel
# Error finding hotel for east london: 'name'
# east london - nearest hotel: No hotel found
# mahabad - nearest hotel: هتل آپارتمان مکریان
# punta arenas - nearest hotel: Hotel Lacolet
# invercargill - nearest hotel: The Grand
# gao - nearest hotel: Tizy Mizy
# tiksi - nearest hotel: Арктика
# tommot - nearest hotel: Томмот
# bokakhat - nearest hotel: Wild Grass
# kailua-kona - nearest hotel: Kona Seaside Hotel
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# ribeira grande - nearest hotel: Hospedaria JSF
# yazman - nearest hotel: Yazman Banquet Marriage Hall
# paradip garh - nearest hotel: Hotel Sea Pearl
# buka - nearest hotel: Brez
# mogok - nearest hotel: Mogok Hill
# punta alta - nearest hotel: Gran Hotel
# talnakh - nearest hotel: Талнах
# chibougamau - nearest hotel: Capissisit Lodge
# hami - nearest hotel: Хами
# amungan - nearest hotel: Tanyaw Beach Resort
# palmer - nearest hotel: La Quinta Inn & Suites
# san patricio - nearest hotel: Best Western Plus
# boa vista - nearest hotel: Aipana Plaza Hotel
# trincomalee - nearest hotel: Summer set inn
# mendi - nearest hotel: Kiburu Lodge
# urucara - nearest hotel: Hotel Catherine
# kapuskasing - nearest hotel: Travelodge
# georgetown - nearest hotel: Page 63 hostel
# Error finding hotel for kyzyl-mazhalyk: 'name'
# kyzyl-mazhalyk - nearest hotel: No hotel found
# lloydminster - nearest hotel: Central Suite Hotel Knight's Inn
# carloforte - nearest hotel: Hotel Riviera
# orapa - nearest hotel: Makumutu Lodge
# Error finding hotel for enewetak: 'name'
# enewetak - nearest hotel: No hotel found
# Error finding hotel for polyarnyy: 'name'
# polyarnyy - nearest hotel: No hotel found
# eureka - nearest hotel: Eureka Inn, Trademark Collection by Wyndham
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# radzyn podlaski - nearest hotel: Hotel President
# divnomorskoye - nearest hotel: панс. Приморский
# thanh pho uong bi - nearest hotel: Khách sạn Thăng Long
# maile - nearest hotel: Adela y Helmut
# pervomayskoye - nearest hotel: Европа
# Error finding hotel for siuna: 'name'
# siuna - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# port elizabeth - nearest hotel: Waterford Hotel
# mahajanga - nearest hotel: Vahiny Hotel
# alta - nearest hotel: Scandic Alta
# walvis bay - nearest hotel: Atlantic
# kourou - nearest hotel: SCI Horizon
# ouargla - nearest hotel: LYNATEL
# batabano - nearest hotel: Motel La Estrella
# toliara - nearest hotel: Ambary
# qarauyl - nearest hotel: laura
# puerto madryn - nearest hotel: Hotel Gran Palace
# Error finding hotel for wabag: 'name'
# wabag - nearest hotel: No hotel found
# ouallam - nearest hotel: Hotel La Girafe
# port saint john's - nearest hotel: Outback Inn
# kapa'a - nearest hotel: Pono Kai Resort
# atafu village - nearest hotel: Luana Liki Hotel
# reghin-sat - nearest hotel: Hotel Monte Cristo
# lemont - nearest hotel: Extended Stay America
# ribeira brava - nearest hotel: Cheerfulway Bravamar Hotel
# loukhi - nearest hotel: Северяночка
# tolanaro - nearest hotel: Hôtel Mahavokey
# alderetes - nearest hotel: Sheraton Tucuman Hotel
# cabo san lucas - nearest hotel: Comfort Rooms
# dudinka - nearest hotel: Виктория
# Error finding hotel for likiep: 'name'
# likiep - nearest hotel: No hotel found
# monticello - nearest hotel: AmericInn Motel - Monticello
# beyneu - nearest hotel: Johan yu
# Error finding hotel for wuyang: 'name'
# wuyang - nearest hotel: No hotel found
# broome - nearest hotel: Quality Inn & Suites
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# sambava - nearest hotel: Royal Sava Hôtel
# mount isa - nearest hotel: Ibis Styles
# smara - nearest hotel: Hôtel Amine فندق الأمين
# vila velha - nearest hotel: Hotel Prainha
# Error finding hotel for adiake: 'name'
# adiake - nearest hotel: No hotel found
# Error finding hotel for quibala: 'name'
# quibala - nearest hotel: No hotel found
# taunsa - nearest hotel: Laraib Hotel & Restaurant
# stanley - nearest hotel: Hotel 52
# misratah - nearest hotel: الفندق السياحى
# filadelfia - nearest hotel: The Ritz-Carlton, Philadelphia
# aasiaat - nearest hotel: SØMA
# ghat - nearest hotel: فندق تاسيلي
# cadale - nearest hotel: Hotel Subiye
# lerwick - nearest hotel: Grand Hotel
# macheng - nearest hotel: 龟峰山庄洪山宾馆
# barkhan - nearest hotel: Muzaffargarh Rest House
# berea - nearest hotel: Residence Inn Cleveland Airport/Middleburg Heights
# mutoko - nearest hotel: Chibhanguza Hotel
# sidney - nearest hotel: The Fullerton Hotel
# tchintabaraden - nearest hotel: Hotel Tarka
# yongchuan - nearest hotel: 時代天街
# Error finding hotel for sarandi del yi: 'name'
# sarandi del yi - nearest hotel: No hotel found
# marco island - nearest hotel: Marco Island Lakeside Inn
# sept-iles - nearest hotel: Château Arnaud
# dutsen wai - nearest hotel: Tee Jay Palace Hotel Zaria
# la passe - nearest hotel: L'Estuaire
# dalandzadgad - nearest hotel: Хан Уул буудал
# gurlan - nearest hotel: Otel nomer 1
# constantia - nearest hotel: Hotel Dali
# st. john's - nearest hotel: Alt Hotel
# akhmim - nearest hotel: فندق نايل تريجر سوهاج
# opuwo - nearest hotel: Ohakane Lodge
# newman - nearest hotel: Hampton Inn & Suites
# jumla - nearest hotel: Amar Sandesh Guesthouse
# puttalam - nearest hotel: Royal Green Garden Hotel
# Error finding hotel for kununurra: 'name'
# kununurra - nearest hotel: No hotel found
# onega - nearest hotel: Гостевой комплекс "Алёнушка"
# neon karlovasion - nearest hotel: Ξενοδοχείο Αιγαίον
# vadso - nearest hotel: Scandic Vadsø
# mukalla - nearest hotel: فندق الجابري
# gulf breeze - nearest hotel: Holiday Inn Express & Suites Gulf Breeze - Pensacola Area
# port lincoln - nearest hotel: Boston Hotel
# qeshm - nearest hotel: هتل آپادانا
# imperatriz - nearest hotel: La Bella Hotel
# rosarito - nearest hotel: WorldMark La Paloma
# beloyarskiy - nearest hotel: Сибирь
# faya-largeau - nearest hotel: فندق ثلاث نجوم بلتن
# katima mulilo - nearest hotel: Zambezi River Lodge
# Error finding hotel for katsuren-haebaru: 'name'
# katsuren-haebaru - nearest hotel: No hotel found
# west wodonga - nearest hotel: Quest Apartments
# Error finding hotel for salekhard: 'name'
# salekhard - nearest hotel: No hotel found
# amalapuram - nearest hotel: Homewood Suites
# mwinilunga - nearest hotel: Guest House le Manguier
# ancud - nearest hotel: Cabañas
# hafar al-batin - nearest hotel: فندق توليب بلازا
# nova sintra - nearest hotel: Residência Ka Dencho
# kidal - nearest hotel: صورن
# guerrero negro - nearest hotel: Plaza sal paraiso
# auki - nearest hotel: Pacific Casino Hotel
# Error finding hotel for les cayes: 'name'
# les cayes - nearest hotel: No hotel found
# Error finding hotel for sumbe: 'name'
# sumbe - nearest hotel: No hotel found
# oroshaza - nearest hotel: Brill Hotel Orosháza
# ust-nera - nearest hotel: гостиница "Солнечная"
# port augusta - nearest hotel: Hotel Commonwealth
# banda aceh - nearest hotel: Hotel 61
# baijiantan - nearest hotel: Heng Long International Hotel
# new norfolk - nearest hotel: Woodbridge on the Derwent
# al kharj - nearest hotel: شقق فندقية
# badagry - nearest hotel: Kappo Hotel
# silvassa - nearest hotel: Lotus Kamat Resort
# kangding - nearest hotel: 溜溜城格桑花大酒店
# prado - nearest hotel: Pousada Recanto do Prado
# bikenibeu village - nearest hotel: Otintaai Hotel
# Error finding hotel for chulakkurgan: 'name'
# chulakkurgan - nearest hotel: No hotel found
# svetlyy - nearest hotel: Гостиница Спортивная
# Error finding hotel for san antonio de pale: 'name'
# san antonio de pale - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# miyako - nearest hotel: ビックウェーブ
# puerto ayacucho - nearest hotel: Hotel VENETUR Amazonas
# Error finding hotel for tsiombe: 'name'
# tsiombe - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# hadibu - nearest hotel: Makka Hotel Bargaal
# el dorado - nearest hotel: Best Western Stagecoach Inn
# kruisfontein - nearest hotel: Savoy
# Error finding hotel for yigo village: 'name'
# yigo village - nearest hotel: No hotel found
# juneau - nearest hotel: Ramada by Wyndham Juneau
# barabai - nearest hotel: Hotel Bouraq
# hanceville - nearest hotel: Days Inn by Wyndham Cullman
# dalhart - nearest hotel: La Quinta Inn & Suites Dalhart
# montelibano - nearest hotel: Montelíbano Plaza
# mirny - nearest hotel: Зарница
# inhambane - nearest hotel: Hotel de Inhambane
# grand baie - nearest hotel: Safari
# cova figueira - nearest hotel: Casa Alcindo
# colonia - nearest hotel: Wasserturm Hotel Cologne
# brisas de zicatela - nearest hotel: Casa de Olas
# san andres - nearest hotel: Hotel Decameron Isleño
# harstad - nearest hotel: Scandic Harstad
# ghadamis - nearest hotel: فندق عين الفارس
# el porvenir - nearest hotel: Hotel Oasis Colonial
# laojunmiao - nearest hotel: 宜必思嘉峪关火车站酒店
# quang ngai - nearest hotel: Ngoc Anh
# sangueya - nearest hotel: Hôtel Kyto
# salinopolis - nearest hotel: Hotel Salinópolis
# vernon - nearest hotel: Okanagan Royal Park Inn
# lompoc - nearest hotel: Red Roof Inn Lompoc
# masterton - nearest hotel: Copthorne Hotel Solway Park
# severnoye - nearest hotel: Юбилейная
# fort bragg - nearest hotel: Airborne Inn Lodging
# la mira - nearest hotel: Hotel La Loma
# westport - nearest hotel: Norwalk Inn and Conference Center
# porto novo - nearest hotel: Hôtel 6500 CFA
# vorkuta - nearest hotel: "Мегаполис"
# coxen hole - nearest hotel: Elizabeth Inn
# sydney - nearest hotel: The Fullerton Hotel
# bardai - nearest hotel: Zaria Hotel
# nguruka - nearest hotel: Galaxy Lodge
# newport - nearest hotel: Queens Hotel
# nuuk - nearest hotel: Nordbo
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# urangan - nearest hotel: Ramada
# bandar lampung - nearest hotel: Grand Anugerah
# santa fe de antioquia - nearest hotel: Hotel Pueblito Viejo
# nampula - nearest hotel: Hotel Lurio
# arkhangel'sk - nearest hotel: Серафима
# griffith - nearest hotel: Quality Inn & Suites Hammond
# Error finding hotel for murun-kuren: 'name'
# murun-kuren - nearest hotel: No hotel found
# paracuru - nearest hotel: Vento Brasil
# dikhil - nearest hotel: Campement touristique À la brise
# chernyshevskiy - nearest hotel: Зарница
# sines - nearest hotel: Sinerama
# ulaangom - nearest hotel: АНДУУД
# bereznik - nearest hotel: Отель Прибрежный
# san agustin - nearest hotel: Microtel Inn & Suites by Wyndham Guadalajara Sur
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# vilyuchinsk - nearest hotel: Победа
# guilin - nearest hotel: 丰源酒店
# mount pearl - nearest hotel: Sandman Signature St. John's Hotel
# kuta - nearest hotel: Ida Hotel Bali
# mugia - nearest hotel: Solpor do Coído
# cidreira - nearest hotel: Hotel Castelo
# hasaki - nearest hotel: Choshi Plaza Hotel
# santarem - nearest hotel: Prático Hotel
# Error finding hotel for barguzin: 'name'
# barguzin - nearest hotel: No hotel found
# bujaru - nearest hotel: Hotel Beira-Rio
# Error finding hotel for arraial do cabo: 'name'
# arraial do cabo - nearest hotel: No hotel found
# cururupu - nearest hotel: Pousada Bom Clima
# namibe - nearest hotel: Nelsal Pensao
# island harbour - nearest hotel: Premier Inn
# ryotsu-minato - nearest hotel: ゆたかや旅館
# kamina - nearest hotel: Hôtel DG
# saldanha - nearest hotel: Hoedjesbaai
# dodoma - nearest hotel: Hilton Lodge 2
# tabou - nearest hotel: hôtel le rochet
# dukhovnitskoye - nearest hotel: Волга
# morez - nearest hotel: Hôtel du Commerce
# Error finding hotel for adygeysk: 'name'
# adygeysk - nearest hotel: No hotel found
# mnichovo hradiste - nearest hotel: U Hroznu
# touros - nearest hotel: Pousada Atlântico
# boguchany - nearest hotel: Полет
# hojai - nearest hotel: Mona Lisa
# kyakhta - nearest hotel: Турист
# tobol'sk - nearest hotel: Ямская
# sona - nearest hotel: Al Bosco
# ilabaya - nearest hotel: Hotel Apu Komayle
# anadyr - nearest hotel: Гостевой дом
# bhera - nearest hotel: Tourist Inn Katas
# coquimbo - nearest hotel: Hotel Iberia
# suva - nearest hotel: Extension 68
# mataram - nearest hotel: hotel solas
# prince rupert - nearest hotel: Crest Hotel
# Error finding hotel for chumphon: 'name'
# chumphon - nearest hotel: No hotel found
# veraval - nearest hotel: Shyam
# la junta - nearest hotel: Travel Inn of La Junta
# egilsstadir - nearest hotel: Valaskjálf
# lai - nearest hotel: Auberge Shalom de Laï
# inirida - nearest hotel: Residencias El Turista del Guainia
# chaozhou - nearest hotel: 桔子潮州古城牌坊街酒店
# nadi - nearest hotel: President Hotel
# gejiu - nearest hotel: 滇越驛沾
# kudahuvadhoo - nearest hotel: Hotel Riu Palace Maldivas
# akrehamn - nearest hotel: Park Inn Haugesund Airport
# bowen - nearest hotel: Whitsunday Sands Resort
# juigalpa - nearest hotel: El Regreso
# zamora - nearest hotel: Hotel Gomar
# kimberley - nearest hotel: Royal Paume Hotel
# sonoita - nearest hotel: La Siesta Motel & RV Resort
# lamu - nearest hotel: Hotel Archipelago villa bed and breakfast
# as samawah - nearest hotel: فندق قصر الغدير
# cranbrook - nearest hotel: Prestige Rocky Mountain Resort Best Western Premier Collection
# ringim - nearest hotel: Ni'Imah Guest Palace
# victorica - nearest hotel: Hotel Mazamet
# akbarpur - nearest hotel: Sai Plaza
# alice springs - nearest hotel: Aurora Alice Springs
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# jeremie - nearest hotel: Delivrance Hotel
# Error finding hotel for ostrovskoye: 'name'
# ostrovskoye - nearest hotel: No hotel found
# ambon - nearest hotel: Hotel Hero
# rafsanjan - nearest hotel: هتل جهانگردی
# nagqu - nearest hotel: Naqu Hotel
# lodja - nearest hotel: Jessica
# mil'kovo - nearest hotel: Дрозды
# zheleznogorsk-ilimskiy - nearest hotel: Магнетит
# yuzhno-kurilsk - nearest hotel: Айсберг
# tyre - nearest hotel: El Boutique Hotel
# taoudenni - nearest hotel: فندق السايح
# san justo - nearest hotel: Hotel España
# labrador city - nearest hotel: Carol Inn
# loa janan - nearest hotel: Putri Ayu Cottage
# kajaani - nearest hotel: Original Sokos Hotel Valjus
# taltal - nearest hotel: Hostería Taltal
# runaway bay - nearest hotel: Cindy Villa
# emerald - nearest hotel: Emerald Central Hotel
# Error finding hotel for leiyang: 'name'
# leiyang - nearest hotel: No hotel found
# barra do corda - nearest hotel: Hotel Belcho
# tobruk - nearest hotel: فندق زهرة البطنان -طبرق
# gibara - nearest hotel: Plaza Colón
# alofi - nearest hotel: Matavai Resort
# alo - nearest hotel: Epe Resort and Spa
# la porte - nearest hotel: Garden Suites Hotel
# uvira - nearest hotel: Batiment Kasangala
# crediton - nearest hotel: Ship Hotel
# nadym - nearest hotel: Янтарная
# khenifra - nearest hotel: Najah
# portland - nearest hotel: the Hoxton
# santa ana - nearest hotel: Holiday Inn Express
# dos hermanas - nearest hotel: Leflet
# isla mujeres - nearest hotel: Villa La Bella
# entebbe - nearest hotel: Airport View Hotel
# kankaanpaa - nearest hotel: Finlandia Hotel Lumiainen
# monrovia - nearest hotel: Bella Casa Hotel
# singkil - nearest hotel: Hotel Universitas Darussalam Gontor
# kloulklubed - nearest hotel: The Adventures Inn
# bubaque - nearest hotel: Chez Julio
# qingyuan - nearest hotel: 好来登国际酒店
# nacozari viejo - nearest hotel: Hotel Pueblo Bonito
# wau - nearest hotel: Safari Park Hotel
# sitka - nearest hotel: Aspen Suites Hotel
# mino - nearest hotel: 箕面観光ホテル
# ajnala - nearest hotel: Radisson Blu Hotel Amritsar
# chios - nearest hotel: Agora Residence
# kapit - nearest hotel: Hotel Haip Choing
# swift current - nearest hotel: York Hotel & Bar
# Error finding hotel for chancay: 'name'
# chancay - nearest hotel: No hotel found
# petrolina - nearest hotel: Neuman
# mccook - nearest hotel: Coratel Inn & Suites By Jasper McCook
# gusinje - nearest hotel: Metro Hotel
# jalai nur - nearest hotel: 满洲里福门客栈
# queenstown - nearest hotel: Queens Hotel
# lincoln city - nearest hotel: Inn at Lincoln City
# fria - nearest hotel: Play Club
# weno - nearest hotel: High Tide Hotel
# kayangel - nearest hotel: M&A Riverside Bungalows
# enoch - nearest hotel: Travelodge Cedar City
# huinan - nearest hotel: ****大酒店
# Error finding hotel for chudniv: 'name'
# chudniv - nearest hotel: No hotel found
# Error finding hotel for achacachi: 'name'
# achacachi - nearest hotel: No hotel found
# adrar - nearest hotel: Auberge Agoueidir
# massakory - nearest hotel: الوطن
# tofol - nearest hotel: Nautilus Resort
# sheikhpura - nearest hotel: Moti Dhabba
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# usogorsk - nearest hotel: Единственная
# gidole - nearest hotel: Green Hotel
# quellon - nearest hotel: Aliwen
# estevan - nearest hotel: Days Inn
# bintulu - nearest hotel: Bakun Inn
# bonthe - nearest hotel: Samies
# moberly - nearest hotel: Super 8 by Wyndham Moberly MO
# puerto aysen - nearest hotel: Hostal Dendal
# Error finding hotel for acarau: 'name'
# acarau - nearest hotel: No hotel found
# santo antonio - nearest hotel: Pousada Onça Puma
# soio - nearest hotel: Hotel Maria Teres
# north platte - nearest hotel: Howard Johnson Inn - North Platte
# yovon - nearest hotel: Sayora.S Hotel
# nova londrina - nearest hotel: Hotel Felice
# al mijlad - nearest hotel: Oasis
# farasan - nearest hotel: Alborg Alwatheer
# midland - nearest hotel: DoubleTree by Hilton Hotel Midland Plaza
# wenling - nearest hotel: Koro
# abadeh - nearest hotel: هتل لاله
# gourcy - nearest hotel: Hôtel Cité Sàrl
# medicine hat - nearest hotel: Ramada
# kiunga - nearest hotel: Cloudlands Hotel
# uturoa - nearest hotel: Hawaiki Nui hotel
# las tablas - nearest hotel: Hotel Don Jesus
# Error finding hotel for amassoma: 'name'
# amassoma - nearest hotel: No hotel found
# cinisi - nearest hotel: Cinisi Vacanze
# nantucket - nearest hotel: Harbor View
# denison - nearest hotel: Clifton House Hotel
# saudarkrokur - nearest hotel: Mikligarður
# Error finding hotel for la'ie: 'name'
# la'ie - nearest hotel: No hotel found
# ak-suu - nearest hotel: BellavistaHotel
# zaozersk - nearest hotel: Северное сияние
# jaguaruna - nearest hotel: Coral Palace Hotel
# salvador - nearest hotel: HOTEL
# sisimiut - nearest hotel: Hotel SØMA
# port isabel - nearest hotel: Queen Isabel Inn
# Error finding hotel for bom jesus da lapa: 'name'
# bom jesus da lapa - nearest hotel: No hotel found
# dolores - nearest hotel: Plaza Hotel
# reynosa - nearest hotel: Hotel Gran Premier
# hsinchu - nearest hotel: 柿子紅快捷旅店
# usinsk - nearest hotel: общежитие Лукойл-Коми
# katabu - nearest hotel: Hotel Dina
# urengoy - nearest hotel: Геолог
# kirakira - nearest hotel: Pacific Casino Hotel
# gulf shores - nearest hotel: Beachside Resort
# plymouth - nearest hotel: Quality Inn
# wad az zaki - nearest hotel: اوضه محمد طه
# anna regina - nearest hotel: Jaigobin Hotel
# Error finding hotel for susuman: 'name'
# susuman - nearest hotel: No hotel found
# buritama - nearest hotel: Hotel Pousada Cidade de Barbosa
# Error finding hotel for searcy: 'name'
# searcy - nearest hotel: No hotel found
# bryne - nearest hotel: Jæren hotell
# kavaratti - nearest hotel: Bangaram Island Beach Resort
# guatire - nearest hotel: Grand Hotel
# lucapa - nearest hotel: Hôtel
# bata - nearest hotel: Elik Melen
# faro - nearest hotel: Best Western Hotel Dom Bernardo
# narrabri - nearest hotel: Tattersall's Hotel
# caldwell - nearest hotel: Best Western Plus Caldwell Inn & Suites
# antofagasta - nearest hotel: Hotel Colón
# uffenheim - nearest hotel: Wellnesshotel Obere Mühle
# hithadhoo - nearest hotel: Pebbles Inn
# fale old settlement - nearest hotel: Luana Liki Hotel
# charters towers - nearest hotel: Pentland Hotel
# port shepstone - nearest hotel: The Spot Backpackers'
# beaugency - nearest hotel: Le Beaugency
# zaruma - nearest hotel: Hotel Blacio
# pointe-du-lac - nearest hotel: Auberge du Lac-Saint-Pierre
# ranau - nearest hotel: Logde 37T
# nemuro - nearest hotel: お宿エクハシ
# sassandra - nearest hotel: Hotel Le Pollet
# aldinga beach - nearest hotel: The Beach Hotel
# nabire - nearest hotel: Hotel Anggrek
# chom thong - nearest hotel: PunYin Hometel
# ezhva - nearest hotel: Тиман
# manay - nearest hotel: RGD Inn
# talakan - nearest hotel: Талакан
# gagliano del capo - nearest hotel: Masseria Palane
# Error finding hotel for andergrove: 'name'
# andergrove - nearest hotel: No hotel found
# puerto carreno - nearest hotel: Carreño Plaza
# yantzaza - nearest hotel: Hotel Sebastian
# amga - nearest hotel: "АммА"
# choyr - nearest hotel: Сансар Хайрхан зочид буудал
# manta - nearest hotel: Hotel Santa Fe
# gadzhiyevo - nearest hotel: Оазис
# naze - nearest hotel: ビジネス旅館畠山
# makanya - nearest hotel: Mchome
# keflavik - nearest hotel: Núpan Deluxe
# hunchun - nearest hotel: 汇泉宾馆
# zhaoqing - nearest hotel: 如家酒店
# desaguadero - nearest hotel: Hostal Don Carlos
# petatlan - nearest hotel: Villa Don Manuel
# pampa - nearest hotel: AmericInn
# kilinochchi - nearest hotel: Raj Hotel
# corfu - nearest hotel: Hotel Bella Venezia
# ta`u - nearest hotel: Sadie's by the Sea
# gordonvale - nearest hotel: Palm Royale Cairns
# heiningen - nearest hotel: Rosa Zeiten
# maceio - nearest hotel: Maceió Hostel e Pousada
# tralee - nearest hotel: The Ashe Hotel
# boyolangu - nearest hotel: Crown Victoria
# Error finding hotel for gotsucho: 'name'
# gotsucho - nearest hotel: No hotel found
# capinota - nearest hotel: Termas La Cabaña de la Torre
# atbara - nearest hotel: Bouchra hotel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    x="Lng",
    y="Lat",
    geo = True,
    tiles = "EsriImagery",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 0.5,
    color = "City",
    hover_cols=["City", "Humidity", "Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
